# %%
'''
Checking safetensors files
'''
from safetensors import safe_open
import torch

# Load from data/llama2-7b-r2d2-lora/5-20-overnight-epsilon-1-outer-lr-1e-5/checkpoint-N
def load_safetensor(N, tensor_name='base_model.model.model.layers.8.self_attn.k_proj.lora_A.weight'):
    with safe_open(f'/root/latent-adversarial-training/models/debug/checkpoint_{N}/adapter_model.safetensors',
                   framework="torch") as f:
        tensor_names = f.keys()
        #print(f"Tensor names: {tensor_names}")
        tensor = f.get_tensor(tensor_name)
        return tensor

def distance(N1, N2):
    tensor1 = load_safetensor(N1)
    tensor2 = load_safetensor(N2)
    return torch.norm(tensor1 - tensor2)

#print(f"40 to 80: {distance(40, 80)}")
#print(f"80 to 120: {distance(80, 120)}")
#print(f"400 to 440: {distance(400, 440)}")

for n in range(1, 10):
    print(f"Norm at {n}: {torch.norm(load_safetensor(n))}")
    print(f"Distance to 1: {distance(1, n)}")
# Out:
# Norm at 1: 4.617921352386475
# Distance to 1: 0.0
# Norm at 2: 4.616186618804932
# Distance to 1: 0.10119445621967316
# Norm at 3: 4.615224838256836
# Distance to 1: 0.13892267644405365
# Norm at 4: 4.614399433135986
# Distance to 1: 0.1777116060256958
# Norm at 5: 4.613775730133057
# Distance to 1: 0.21815675497055054
# Norm at 6: 4.612754821777344
# Distance to 1: 0.22297786176204681
# Norm at 7: 4.612367630004883
# Distance to 1: 0.24448683857917786
# Norm at 8: 4.6116042137146
# Distance to 1: 0.2525393068790436
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 26
#      21 #print(f"40 to 80: {distance(40, 80)}")
#      22 #print(f"80 to 120: {distance(80, 120)}")
#      23 #print(f"400 to 440: {distance(400, 440)}")
#      25 for n in range(1, 10):
# ---> 26     print(f"Norm at {n}: {torch.norm(load_safetensor(n))}")
#      27     print(f"Distance to 1: {distance(1, n)}")
#
# Cell In[10], line 9, in load_safetensor(N, tensor_name)
#       8 def load_safetensor(N, tensor_name='base_model.model.model.layers.8.self_attn.k_proj.lora_A.weight'):
# ----> 9     with safe_open(f'/root/latent-adversarial-training/models/debug/checkpoint_{N}/adapter_model.safetensors',
#      10                    framework="torch") as f:
#      11         tensor_names = f.keys()
#      12         #print(f"Tensor names: {tensor_names}")
#
# FileNotFoundError: No such file or directory: "/root/latent-adversarial-training/models/debug/checkpoint_9/adapter_model.safetensors"
